# %% [markdown]
# <a href="https://colab.research.google.com/github/Alit10/deep_learning/blob/master/pet_application1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r --upgrade 'gdrive/My Drive/Colab Notebooks/pet/requirements.txt'
# Out:
# ERROR: Invalid requirement: 'gdrive/My Drive/Colab Notebooks/pet/requirements.txt'
# Hint: It looks like a path. File 'gdrive/My Drive/Colab Notebooks/pet/requirements.txt' does not exist.

# %%
from google.colab import files, drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install transformers
# !pip install jsonpickle

# %%
# !python 'gdrive/My Drive/Colab Notebooks/pet/cli.py'  --method pet --pattern_ids 0 1 2 \
--data_dir 'gdrive/My Drive/Colab Notebooks/pet/data/yelp' --model_type albert  \
--model_name_or_path albert-large-v1 --task_name yelp-polarity \
--output_dir 'gdrive/My Drive/Colab Notebooks/pet/output' --do_train --do_eval \
--pet_per_gpu_eval_batch_size 128 --pet_max_steps 50 \
--pet_max_seq_length 256 --pet_repetitions 1 \
--train_examples 10 --test_examples 2 \
--pet_per_gpu_train_batch_size 2 --sc_per_gpu_unlabeled_batch_size 2 \
--pet_gradient_accumulation_steps 16 --sc_gradient_accumulation_steps 16
# Out:
# 2020-11-26 18:28:04.183638: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ---------------------------ok------------------
# ---------------------------ok1------------------
# ---------------------------training pet------------------
# evaluation before training
# the device used is cuda
# train single model eval
# prepare eval dataset
# converting examples to features
# length of examples 10
# 0
# examples converted in the generated dataset
# eval dataset generated
# per gpu eval dataset ok
# eval_dataloader
# start of the batch eval
# mlm
# Evaluating:   0% 0/1 [00:00<?, ?it/s]the step2 duration is 1606415313.0983431
# Evaluating: 100% 1/1 [00:03<00:00,  3.84s/it]
# ...

# %%
# !ls 'gdrive/My Drive/Colab Notebooks/pet'
# Out:
# cli.py	examples  log.py  __pycache__  requirements.txt
# data	LICENSE   pet	  README.md    Untitled0.ipynb
